# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
both_wine = pd.read_pickle('both_wine.pkl')

# %%
both_wine_feat = list(both_wine)

# %%
wines = both_wine.as_matrix()

# %%
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn import mixture

kmeans = {'kmeans_2_20': KMeans(n_clusters=2,n_init=20,random_state=5),
          'kmeans_3_20': KMeans(n_clusters=3,n_init=20,random_state=5),
          'kmeans_4_20': KMeans(n_clusters=4,n_init=20,random_state=5),
          'kmeans_5_20': KMeans(n_clusters=5,n_init=20,random_state=5),
          'kmeans_6_20': KMeans(n_clusters=6,n_init=20,random_state=5)
         }
aggloms = {'agglomerative_2_eucl': AgglomerativeClustering(n_clusters=2,affinity='euclidian'),
           'agglomerative_3_eucl': AgglomerativeClustering(n_clusters=3,affinity='euclidian'),
           'agglomerative_4_eucl': AgglomerativeClustering(n_clusters=4,affinity='euclidian'),
           'agglomerative_5_eucl': AgglomerativeClustering(n_clusters=5,affinity='euclidian'),
           'agglomerative_6_eucl': AgglomerativeClustering(n_clusters=6,affinity='euclidian')
          }
gmms = {'gm_2_full_1_kmeans': mixture.GMM(n_components=2,covariance_type='full',n_init=1,init_params='kmeans',random_state=5),
        'gm_3_full_1_kmeans': mixture.GMM(n_components=3,covariance_type='full',n_init=1,init_params='kmeans',random_state=5),
        'gm_4_full_1_kmeans': mixture.GMM(n_components=4,covariance_type='full',n_init=1,init_params='kmeans',random_state=5),
       }

# %%
fignum = 1
from mpl_toolkits.mplot3d import Axes3D
from sklearn import metrics
from sklearn.metrics import pairwise_distances

for name, est in estimators.items():
    fig = plt.figure(fignum, figsize=(4,3))
    plt.clf()
    ax = Axes3D(fig, rect=[1, 2, 2, 3], elev=10, azim=135)
    
    plt.cla()
    est.fit(wines)
    labels = est.labels_
    centroids = est.cluster_centers_
    
    ax.scatter(wines[:,0],wines[:,1],wines[:,2],c=labels.astype(np.float))
    plt.title(name)
    
    ax.w_xaxis.set_ticklabels([])
    ax.w_yaxis.set_ticklabels([])
    ax.w_zaxis.set_ticklabels([])
    ax.set_xlabel('fixed acidity')
    ax.set_ylabel('volatile acidity')
    ax.set_zlabel('citric acid')
    
    from sklearn import metrics
    from sklearn.metrics import pairwise_distances

    print(metrics.silhouette_score(wines,labels,metric='euclidean'))
    
    fignum = fignum + 1
# Out:
# 0.504059037897
# 0.391131140543
# 0.450436828194
# 0.509428237621
# 0.417664115506

# %%
    ax.scatter(wines[:,3],wines[:,4],wines[:,5],c=labels.astype(np.float))
    
    

    metrics.silhouette_score(wines,labels,metric='euclidean')
    
    ax.w_xaxis.set_ticklabels([])
    ax.w_yaxis.set_ticklabels([])
    ax.w_zaxis.set_ticklabels([])
    ax.set_xlabel('residual sugar')
    ax.set_ylabel('chlorides')
    ax.set_zlabel('free sulfur dioxide')

# %%
from sklearn import metrics
from sklearn.metrics import pairwise_distances

metrics.silhouette_score(wines,labels,metric='euclidean')
# Out:
# 0.50405903789665418

# %%
print(labels)
# Out:
# [1 1 1 ..., 0 1 1]

# %%
for i in range(k):
    obs = wines[np.where(labels==i)]
    plt.plot(obs[:,8],obs[:,1],'o')
    lines = plt.plot(centroids[i,0],centroids[i,1],'kx')
    plt.setp(lines,ms=2.0)
    plt.setp(lines,mew=2.0)
